# %%
rcParams['font.size']=24
rcParams['savefig.dpi']=100
rcParams['figure.figsize']=(12,9)
rcParams['figure.subplot.hspace']=.6
rcParams['axes.linewidth']=2.0
rcParams['axes.grid']=True

# %%
import attenuation_turns_converter

# %%
### All sweeps taken at -20 dB attenuation. ###

# %%
# Baseline sweeps taken with just the short waveguide between the mmwave source and ZBD.

for i in range(1,4):
    ac=attenuation_turns_converter.attenuationConverter(datafile=('2014-06-20_baseline_sweep%d.npz'%i))
    freq = numpy.array(ac.data['freq']) * 12 / 1e9
    plot(freq, ac.give_dbm(ac.data['x']), '.')
    xlim(140, 160)
