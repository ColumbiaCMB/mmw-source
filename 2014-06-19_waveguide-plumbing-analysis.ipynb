# %%
rcParams['font.size']=24
rcParams['savefig.dpi']=100
rcParams['figure.figsize']=(12,9)
rcParams['figure.subplot.hspace']=.6
rcParams['axes.linewidth']=2.0
rcParams['axes.grid']=True

# %%
import attenuation_turns_converter

# %%
low_res = attenuation_turns_converter.attenuationConverter(datafile='2014-06-18_low_res_-20dB.npz')
high_res = attenuation_turns_converter.attenuationConverter(datafile='2014-06-18_high_res_-20dB.npz')

# %%
plot(low_res.data['freq'], low_res.data['x'])
plot(high_res.data['freq'], high_res.data['x'])

# %%
# It seems that the attenuation was turned too high. Retry these tests with a set attenuation.
